# %% [markdown]
# # Pau's notebook holidays

# %% [markdown]
# Ths purpose of this notebook is to get used with _python_ and __jupyter__ and write some ideas for Pau holidays.

# %%
name = input("Introduce your name: ")

#print("Your name is: " + name)
# Out:
# Introduce your name: Pau
# Your name is: Pau

# %%
#I tried diferent methods to insert an image
#<img src="843690318225061576y121.jpg" width="400" height="500">

# %%
#from IPython.display import Image
#Image(src='843690318225061576y121.jpg', width=200)

# %%
#<img src =attachment:843690318225061576y121.jpg width = "300" height = "500" >

# %% [markdown]
# ![PauP](attachment:5843690318225061576y121.jpg)

# %%
holnam = input("Name of your favorite holiday: ")
inidate = input("When does it start? dd-mm ")
enddate = input("When does it end? dd-mm ")
# Out:
# Name of your favorite holiday: Summer holidays on Norway
# When does it start? dd-mm 20-07
# When does it end? dd-mm 01-08

# %% [markdown]
# <img src="https://blog-assets.busbud.com/wp-content/uploads/2019/11/Sunnylvsfjorden-fjord-canyon.png">

# %% [markdown]
# Best things to do on __Norway__
#
# - Ski
# - Hiking
# - _Kayaking_
#
#
# <span style="color:green">There are lots of activities to do on Norway</span>

# %%
#Run this block and you will get an embeded video
from IPython.display import YouTubeVideo

YouTubeVideo('ML-JwZIxno0', width=800, height=300)

# %%
print("Your favourite holidays are " + holnam )
print("And you get from " + inidate + " to " + enddate)
# Out:
# Your favourite holidays are Semana santa
# And you get from 12-04-21 to 23-04-21
